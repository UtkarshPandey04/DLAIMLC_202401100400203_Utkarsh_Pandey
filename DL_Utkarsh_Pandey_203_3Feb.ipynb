# %%
import tensorflow as tf
import numpy as np

#step1: convert data to numpy arrays
x=np.array([1,2,3,4],dtype=float);
y=np.array([2,4,6,8],dtype=float);

#step 2: Define model using input layer(recommended)
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)), #preferred over input_shape in Dense
    tf.keras.layers.Dense(1)
])

# step 3: compile the model

model.compile(optimizer='sgd',loss='mean_squared_error')

#step 4: train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - loss: 3.5837
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.4889
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.7292
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.2021
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.8363
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5824
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4063
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2841
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1992
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1404

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# Step 1: Convert data to numpy arrays
x = np.array([1, 2, 3, 4], dtype=float)
y = np.array([2, 4, 6, 8], dtype=float)

# Step 2: Define model
model = Sequential([
    Dense(1, input_shape=(1,))
])

# Step 3: Compile model
model.compile(optimizer='sgd', loss='mse')

# Step 4: Train model
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 3.3773
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.3456
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6296
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.1328
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.7881
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5489
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3829
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2677
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1878
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1323

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#define a simple linear model
model=nn.Linear(1,1)

#Define the loss function and optimizer
criterion=nn.MSELoss()
optimizer=optim.SGD(model.parameters(),lr=0.01)

#dummy data
x=torch.tensor([[1.],[2.],[3.],[4.]])
y=torch.tensor([[2.],[4.],[6.],[8.]])

#Training Loop
for epoch in range(10):
  optimizer.zero_grad()
  outputs=model(x)
  loss=criterion(outputs,y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1},Loss:{loss.item()}")
# Out:
# Epoch 1,Loss:57.39813232421875
# Epoch 2,Loss:39.90732192993164
# Epoch 3,Loss:27.770336151123047
# Epoch 4,Loss:19.3482666015625
# Epoch 5,Loss:13.503898620605469
# Epoch 6,Loss:9.448144912719727
# Epoch 7,Loss:6.633476257324219
# Epoch 8,Loss:4.679974555969238
# Epoch 9,Loss:3.324019432067871
# Epoch 10,Loss:2.3826918601989746
